# %%
import os

# %%
for filename in os.listdir('/Users/jito/GitHub/joi.github.io/recipes'):
#    if filename.endswith(".asm") or filename.endswith(".py"): 
        print(os.path.join('/Users/jito/GitHub/joi.github.io/recipes', filename))
  #      continue
 #   else:
 #       continue
# Out:
# /Users/jito/GitHub/joi.github.io/recipes/No Knead Bread.html
# /Users/jito/GitHub/joi.github.io/recipes/Fried Chicken for Two.html
# /Users/jito/GitHub/joi.github.io/recipes/Steak Haché.html
# /Users/jito/GitHub/joi.github.io/recipes/Braised Chicken Thighs and Legs with Tomato.html
# /Users/jito/GitHub/joi.github.io/recipes/How to Cook (And Shred) a Pork Shoulder for Pulled Pork.html
# /Users/jito/GitHub/joi.github.io/recipes/Hamburger Steak.html
# /Users/jito/GitHub/joi.github.io/recipes/Salmon with Sesame and Herbs.html
# /Users/jito/GitHub/joi.github.io/recipes/Cast-Iron Steak.html
# /Users/jito/GitHub/joi.github.io/recipes/Pan Seared Garlic Butter Steak & Mushroom Cream Sauce.html
# /Users/jito/GitHub/joi.github.io/recipes/Steamed Mussels with Garlic and Parsley.html
# /Users/jito/GitHub/joi.github.io/recipes/Slow Cooker Salsa Verde Chicken.html
# /Users/jito/GitHub/joi.github.io/recipes/Biltmore Chianti Glazed Beef Short Ribs.html
# ...
